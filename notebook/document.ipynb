# %%
## Document Structure

from langchain_core.documents import Document

# %%
doc=Document(
    page_content="This is a sample content I am using to create RAG",
    metadata={
        "source": "sample.txt",
        "pages": 1,
        "author": "Sahil",
        "date_created": "2026-07-06"
    }
)
doc
# Out:
# Document(metadata={'source': 'sample.txt', 'pages': 1, 'author': 'Sahil', 'date_created': '2026-07-06'}, page_content='This is a sample content I am using to create RAG')

# %%
## Create a simple txt file
import os
os.makedirs("../data/text_files",exist_ok=True)

# %%
sample_texts={
    "../data/text_files/python_intro.txt":"""Python Programming Introduction

Python is a high-level, interpreted programming language known for its simplicity and readability.
Created by Guido van Rossum and first released in 1991, Python has become one of the most popular
programming languages in the world.

Key Features:
- Easy to learn and use
- Extensive standard library
- Cross-platform compatibility
- Strong community support

Python is widely used in web development, data science, artificial intelligence, and automation.""",
    
    "../data/text_files/machine_learning.txt": """Machine Learning Basics

Machine learning is a subset of artificial intelligence that enables systems to learn and improve
from experience without being explicitly programmed. It focuses on developing computer programs
that can access data and use it to learn for themselves.

Types of Machine Learning:
1. Supervised Learning: Learning with labeled data
2. Unsupervised Learning: Finding patterns in unlabeled data
3. Reinforcement Learning: Learning through rewards and penalties

Applications include image recognition, speech processing, and recommendation systems
    
    
    """

}

for filepath,content in sample_texts.items():
    with open(filepath,'w',encoding="utf-8") as f:
        f.write(content)

print("✅ Sample text files created!")
# Out:
# ✅ Sample text files created!

# %%
### TextLoader

from langchain_community.document_loaders import TextLoader

loader=TextLoader("../data/text_files/python_intro.txt",encoding="utf-8")
document=loader.load()
print(document)
# Out:
# [Document(metadata={'source': '../data/text_files/python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
### Directory Loader
from langchain_community.document_loaders import DirectoryLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/text_files",
    glob="**/*.txt", ## Pattern to match files  
    loader_cls= TextLoader, ##loader class to use
    loader_kwargs={'encoding': 'utf-8'},
    show_progress=False

)

documents=dir_loader.load()
documents
# Out:
# [Document(metadata={'source': '..\\data\\text_files\\machine_learning.txt'}, page_content='Machine Learning Basics\n\nMachine learning is a subset of artificial intelligence that enables systems to learn and improve\nfrom experience without being explicitly programmed. It focuses on developing computer programs\nthat can access data and use it to learn for themselves.\n\nTypes of Machine Learning:\n1. Supervised Learning: Learning with labeled data\n2. Unsupervised Learning: Finding patterns in unlabeled data\n3. Reinforcement Learning: Learning through rewards and penalties\n\nApplications include image recognition, speech processing, and recommendation systems\n\n\n    '),
#  Document(metadata={'source': '..\\data\\text_files\\python_intro.txt'}, page_content='Python Programming Introduction\n\nPython is a high-level, interpreted programming language known for its simplicity and readability.\nCreated by Guido van Rossum and first released in 1991, Python has become one of the most popular\nprogramming languages in the world.\n\nKey Features:\n- Easy to learn and use\n- Extensive standard library\n- Cross-platform compatibility\n- Strong community support\n\nPython is widely used in web development, data science, artificial intelligence, and automation.')]

# %%
from langchain_community.document_loaders import PyPDFLoader, PyMuPDFLoader

## load all the text files from the directory
dir_loader=DirectoryLoader(
    "../data/pdf",
    glob="**/*.pdf", ## Pattern to match files  
    loader_cls= PyMuPDFLoader, ##loader class to use
    show_progress=False

)

pdf_documents=dir_loader.load()
pdf_documents
# Out:
# [Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with hyperref', 'creationdate': '2026-07-01T16:50:10+00:00', 'source': '..\\data\\pdf\\SahilDargar_23244_Resume.pdf', 'file_path': '..\\data\\pdf\\SahilDargar_23244_Resume.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': '', 'author': '', 'subject': '', 'keywords': '', 'moddate': '2026-07-01T16:50:10+00:00', 'trapped': '', 'modDate': 'D:20260701165010Z', 'creationDate': 'D:20260701165010Z', 'page': 0}, page_content='Sahil Dargar\n+91-8882386329\nRoll No.:23244\nsahildargar@gmail.com\nB.Tech - Electronics and Communication Engineering\nGithub\nIndian Institute Of Information Technology, Una\nlinkedin.com/in/dargar1726\nEducation\nDegree/Certificate\nInstitute/Board\nCGPA/Percentage\nYear\nB.Tech\nIndian Institute of Information Technology, Una\n7.53 (Current)\n2023-Present\nSenior Secondary\nCBSE Board\n93.2%\n2022\nSecondary\nCBSE Board\n94.8%\n2020\nProjects\n• MindEase\nJul 2025 - Sep 2025\nPracticum, IIIT Una\nWebsite\n– Designed an AI-assisted mental health platform supporting 100+ journal entries per user, enabling emotional\nwell-being monitoring through natural language journaling and early identification of recurring mood patterns.\n– Applied NLP techniques using NLTK and spaCy to analyze textual data, performing real-time sentiment detection\nand emotion classification across 5+ emotional categories for personalized insights.\n– Implemented interactive visualization dashboards by aggregating backend data and rendering emotional trends\nover time, allowing users and clinicians to track weekly and monthly behavioral patterns efficiently.\n• QuickBlog\nMay 2025 - June 2025\nPracticum, IIIT Una\nGithub\n– Built an AI-enabled blogging platform using the MERN stack, supporting multiple user roles with clearly separated\nadmin and user dashboards.\n– Developed and maintained 15+ API endpoints to manage authentication, blog and comment lifecycles, and analytics\ndata for administrative insights.\n– Automated content generation by integrating third-party AI services, achieving a 40% reduction in content creation\ntime, and utilized ImageKit for efficient cloud-based image optimization and delivery.\n• Jobify\nNov. 2024 - Dec. 2024\nPracticum, IIIT Una\nWebsite\n– Engineered a scalable MERN-based job portal capable of handling 100+ concurrent users, providing secure au-\nthentication, job discovery, and resume management through real-time CRUD operations.\n– Constructed and optimized 10+ RESTful APIs for users, jobs, companies, and applications, leveraging JWT\nauthentication and role-based authorization.\n– Optimized state management and file processing by leveraging Redux Toolkit and Multer, resulting in 30% faster\nresume and profile update workflows.\n– Designed a responsive and accessible user interface using React (Vite) and Shadcn UI, enabling advanced job\nfiltering, application tracking, and an admin dashboard overseeing 50+ job listings.\nTechnical Skills\n• Programming:Python, C, Java, Javascript, Typescript\n• Frameworks:ReactJS, NodeJS, ExpressJS, Redux, Tailwind CSS, NextJs\n• Developer Tools:VS Code, Git, Postman, MongoDB Compass, Docker, Redis\n• AI / GenAI:LLMs, RAG, AI Agents, LangChain, LangGraph, Gemini API, OpenAI API, Tool Calling\nKey courses taken\n• Computer Science:Data Structures and Algorithm, Computer Networks, OOPS, OS\n• Electronics:Control Systems, Digital Systems, Microprocessors, Microwaves\nPositions of Responsibility\n• Vice President,Entrepreneurship and Incubation Cell, IIIT Una\nOct 2025 - Present\n• Joint Secretary,Entrepreneurship and Incubation Cell, IIIT Una\nMar 2025 - Oct 2025\n• Executive Member,Entrepreneurship and Incubation Cell, IIIT Una\nMar 2024 - Mar 2025\nAchievements\n• 450+ DSA question, Leetcode, GFG\n2025\n• Core Organizer - Hack The Hills, Organized college’s first inter college hackathon\n2025\n• 97%ile, JEE Mains, ranking among the top 3% in 10+ lakhs of aspirants\n2023\n• District Player, Footba ...
#  Document(metadata={'producer': 'pdfTeX-1.40.26', 'creator': 'LaTeX with RenderCV', 'creationdate': '2026-07-01T16:36:51+00:00', 'source': '..\\data\\pdf\\Sahil_D.pdf', 'file_path': '..\\data\\pdf\\Sahil_D.pdf', 'total_pages': 1, 'format': 'PDF 1.5', 'title': "John Doe's CV", 'author': 'John Doe', 'subject': '', 'keywords': '', 'moddate': '2026-07-01T16:36:51+00:00', 'trapped': '', 'modDate': 'D:20260701163651Z', 'creationDate': 'D:20260701163651Z', 'page': 0}, page_content='SAHIL DARGAR\nsahildargar@gmail.com | +918882386329 | linkedin.com/in/dargar1726 | github.com/sahil-dev-eloper\nEducation\nIndian Institute of Information Technology, Una\nB.Tech. in Electronics and Communication Engineering - 7.53 CGPA\nAugust 2023 – May 2027\nSecondary School Examination (CBSE)\nVatsalya Public School, Mathura - 93.2%\nMay 2022\nSenior Secondary School Examination (CBSE)\nBKS Vidya Mandir, Mathura - 94.8%\nMarch 2020\nTechnical Skills\nLanguages: Python, C, Java, HTML, CSS, Javascript, Typescript, SQL\nFrameworks and Libraries: ReactJS, NodeJS, ExpressJS, Redux, Tailwind CSS, NextJs\nAI / GenAI: LLMs, AI Agents, LangChain, LangGraph, RAG, Gemini API, OpenAI API, Tool Calling\nDeveloper Tools & Database: VS Code, Git, Postman, MongoDB Compass, MongoDB, Docker, Redis\nCourses: Data Structure and Algorithms, Computer Networks, Object Oriented Programming, OS\nProjects\nJobify\nLive\n• Engineered a scalable MERN-based job portal supporting 100+ concurrent users with secure JWT\nauthentication and role-based access control.\n• Tested 10+ RESTful APIs to manage users, jobs, companies, and applications with optimized data handling.\n• Structured a fully responsive React (Vite) + Shadcn UI interface using Redux Toolkit and Multer, enabling\ndynamic job filtering, resume uploads, and management of 50+ job listings, improving response efficiency by\n30%.\nQuickBlog\nGithub\n• Developed an AI-powered blogging platform using the MERN stack with distinct user roles and dedicated\nadmin and user dashboards.\n• Designed and implemented 15+ API endpoints for authentication, blog and comment management, and\nanalytics tracking.\n• Integrated third-party AI services for automated content generation, reducing creation time by 40%, and utilized\nImageKit for optimized cloud image storage and fast media delivery.\nMindEase\nLive\n• Built an AI-driven mental health platform supporting 100+ journal entries per user with natural\nlanguage-based mood tracking.\n• Inserted NLP pipelines using NLTK and spaCy for real-time sentiment analysis across 5+ emotional\ncategories.\n• Made interactive dashboards to visualize weekly and monthly behavioral insights, enabling early detection\nof recurring mood patterns.\nPositions / Responsibilities\nVice President, Entrepreneurship and Incubation Cell: Led 10+ initiatives and operations for the E-Cell.\nCore Organizer, Hack The Hills: Organized the institute’s first inter-college coding hackathon.\nEvent Organizer, E-Summit: Contributed to organizing the institute’s first E-Summit.\nAchievements\nAcademics: Solved 450+ DSA questions (Java) on LeetCode and GFG.\nSports: Played Football at District Level, Runner-up in Chess at school competition.')]
